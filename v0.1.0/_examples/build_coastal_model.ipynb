# %% [markdown]
# # Make a coastal sfincs model from scratch using hydromt

# %% [markdown]
# This notebook demonstrates how to prepare and inspect a SFINCS model from scratch. The notebook does not contain the SFINCS code or executables to run the model with.
#
# We will make a schematization with the following features:
# * we only simulate coastal flooding, we do not consider any interactions with riverine flooding
# * we use the MERIT Hydro dataset as elevation
# * we include boundary conditions from the Global Tide and Surge Model by imposing a number of boundary points    where forcing is expected

# %% [markdown]
# All lines in this notebook which start with `!` are executed from the command line. Within the notebook environment the logging messages are shown after completion. You can also copy these lines and paste these in your shell to get more direct feedback.

# %% [markdown]
# ### HydroMT CLI build interface

# %% [markdown]
# First let us see what hydromt provides us with.

# %%
# !hydromt --help
# Out:
# Usage: hydromt [OPTIONS] COMMAND [ARGS]...
#
#   Command line interface for hydromt models.
#
# Options:
#   --version  Show the version and exit.
#   --models   Print availabe model plugins and exit.
#   --help     Show this message and exit.
#
# Commands:
#   build   Build models
#   clip    Clip models.
#   update  Update models

# %% [markdown]
# Whith the `models` flag we can ask if hydromt recognizes the SFINCS plugin (sfincs should be mentioned):

# %%
# !hydromt --models
# Out:
# hydroMT model plugins: sfincs (v0.1.0)

# %% [markdown]
# It looks like we have several commands that we can consider. We want to `build` a model. How does that work? We can also call `--help` on the available hydromt commands as follows.

# %%
# !hydromt build --help
# Out:
# Usage: hydromt build [OPTIONS] MODEL MODEL_ROOT REGION
#
#   Build models from source data.
#
#   Example usage:
#   --------------
#
#   To build a wflow model for a subbasin using and point coordinates snapped to cells with stream order >= 4
#   hydromt build wflow /path/to/model_root "{'subbasin': [-7.24, 62.09], 'strord': 4}" -i /path/to/wflow_config.ini
#
#   To build a wflow model based on basin ID
#   hydromt build wflow /path/to/model_root "{'basin': 230001006}"
#
#   To build a sfincs model based on a bbox (for Texel)
#   hydromt build sfincs /path/to/model_root "{'bbox': [4.6891,52.9750,4.9576,53.1994]}"
#
# Options:
#   -r, --res FLOAT             Model resolution in model src.
#   --build-base / --build-all  Deprecated!
#   --opt TEXT                  Component specific keyword arguments, see the
#                               setup_<component> method of the specific model
#                               for more information about the arguments.
#
#   -i, --config PATH           Path to hydroMT configuration file, for the
#                               model specific implementation.
#
#   -d, --data PATH             File path to yml data sources file. See
#                               documentation for required yml file format.
#
#   --dd, --deltares-data       Parse default deltares data yml from
#                               https://github.com/DirkEilander/hydromt-
#                               artifacts/releases
#
#   -q, --quiet                 Decrease verbosity.
#   -v, --verbose               Increase verbosity.
#   --help                      Show this message and exit.

# %% [markdown]
# ### Building a first model (and getting an error when data is missing)
# Let's try to build an entire schematisation, just from the command line (Awesome!!!). In the `--help` section, there is an example for making a model from a bounding box, which is very intuitive. Let's try exactly that. We store the model on the local path `./texel_sfincs`

# %%
# !hydromt build sfincs ./texel_sfincs "{'bbox': [4.6891,52.9750,4.9576,53.1994]}"
# Out:
# 2021-05-18 09:07:04,457 - build - model_api - WARNING - Model dir already exists and files might be overwritten: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/texel_sfincs/.
# 2021-05-18 09:07:07,303 - build - main - ERROR - index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/cli/main.py", line 196, in build
#     mod.build(region, res, opt=opt)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/models/model_api.py", line 141, in build
#     self._run_log_method("setup_basemaps", **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/models/model_api.py", line 99, in _run_log_method
#     return func(*args, **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/sfincs.py", line 260, in setup_basemaps
#     da_elv.raster.clip_geom(geom=dst_geom, buffer=5)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 861, in clip_geom
#     obj_clip.coords["mask"] = obj_clip.raster.geometry_mask(geom)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 961, in geometry_mask
#     return self.rasterize(
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 925, in rasterize
#     transform=self.transform,
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 363, in transform
#     *self.internal_bounds, self.width, self.height
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 370, in internal_bounds
#     res_x, res_y = self.res
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 396, in res
#     left, right = float(self.xcoords[0]), float(self.xcoords[-1])
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/dataarray.py", line 707, in __getitem__
#     return self.isel(indexers=self._item_key_to_dict(key))
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/dataarray.py", line 1130, in isel
#     variable = self._variable.isel(indexers, missing_dims=missing_dims)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/variable.py", line 1153, in isel
#     return self[key]
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/variable.py", line 794, in __getitem__
#     data = as_indexable(self._data)[indexer]
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/indexing.py", line 1470, in __getitem__
#     result = self.array[key]
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 4297, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Traceback (most recent call last):
#   File "/usr/share/miniconda/envs/hydromt-sfincs/bin/hydromt", line 8, in <module>
#     sys.exit(main())
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/click/decorators.py", line 21, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/cli/main.py", line 196, in build
#     mod.build(region, res, opt=opt)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/models/model_api.py", line 141, in build
#     self._run_log_method("setup_basemaps", **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/models/model_api.py", line 99, in _run_log_method
#     return func(*args, **kwargs)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/sfincs.py", line 260, in setup_basemaps
#     da_elv.raster.clip_geom(geom=dst_geom, buffer=5)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 861, in clip_geom
#     obj_clip.coords["mask"] = obj_clip.raster.geometry_mask(geom)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 961, in geometry_mask
#     return self.rasterize(
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 925, in rasterize
#     transform=self.transform,
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 363, in transform
#     *self.internal_bounds, self.width, self.height
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 370, in internal_bounds
#     res_x, res_y = self.res
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt/raster.py", line 396, in res
#     left, right = float(self.xcoords[0]), float(self.xcoords[-1])
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/dataarray.py", line 707, in __getitem__
#     return self.isel(indexers=self._item_key_to_dict(key))
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/dataarray.py", line 1130, in isel
#     variable = self._variable.isel(indexers, missing_dims=missing_dims)
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/variable.py", line 1153, in isel
#     return self[key]
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/variable.py", line 794, in __getitem__
#     data = as_indexable(self._data)[indexer]
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/xarray/core/indexing.py", line 1470, in __getitem__
#     result = self.array[key]
#   File "/usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 4297, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# The above might have taken a few seconds, but then should have miserably crashed! What happened:
# * HydroMT was looking for a data catalog to use.
# * It did not find any and therefore, it automatically downloaded a sample data catalog which you can now find on your home folder under .hydromt_data
# * It tried to build a model in the Texel bounding box, but...alas, the sample dataset does not cover Texel at all! To add datasets covering the area outside the sample data extent, setup your own datasets using data yml files [hydromt data](https://deltares.github.io/hydromt/latest/user_guide/data.html) using `--data PATH` option, or if your are connected to the deltares network `--deltares-data` flag.

# %% [markdown]
# ### Building a first model (and getting it right)
# Let's adapt the bounding box to an area that fits within the sample dataset. The dataset covers the Piave basin and its surroundings in Italy. A good place to get a CSV formatted bounding box is https://boundingbox.klokantech.com/
#
# We also add `-vv` for extra verbosity

# %%
# !hydromt build sfincs ./venice_sfincs "{'bbox': [12.047909,45.15809,12.833432,45.646944]}" -vv
# Out:
# 2021-05-18 09:07:09,188 - build - log - DEBUG - Writing log messages to new file /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs/hydromt.log.
# 2021-05-18 09:07:09,188 - build - log - INFO - HydroMT version: 0.4.1
# 2021-05-18 09:07:09,188 - build - main - INFO - Building instance of sfincs model at /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs.
# 2021-05-18 09:07:09,188 - build - main - INFO - User settings:
# 2021-05-18 09:07:09,188 - build - model_api - INFO - Initializing sfincs model from hydromt_sfincs (v0.1.0).
# 2021-05-18 09:07:09,188 - build - model_api - WARNING - Model dir already exists and files might be overwritten: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs/.
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.region: {'bbox': [12.047909, 45.15809, 12.833432, 45.646944]}
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.res: 100
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.crs: utm
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.basemaps_fn: merit_hydro
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.basin_index_fn: merit_hydro_index
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.landmask_fn: osm_landareas
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.bathymetry_fn: gebco
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.mdt_fn: dtu10mdt_egm96
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.merge_buffer: 0
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.mask_fn: None
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.dep_contour: -1
# 2021-05-18 09:07:09,189 - build - model_api - INFO - setup_basemaps.method: bilinear
# 2021-05-18 09:07:09,189 - build - data_adapter - INFO - Updating data sources from yml file /home/runner/.hydromt_data/data/v0.0.4/data_catalog.yml
# 2021-05-18 09:07:09,253 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/merit_hydro/{variable}.tif
# 2021-05-18 09:07:09,329 - build - basin_mask - DEBUG - Parsed region (kind=bbox): {'bbox': [12.047909, 45.15809, 12.833432, 45.646944]}
# 2021-05-18 09:07:09,506 - build - data_adapter - INFO - DataCatalog: Getting osm_landareas GeoDataFrame vector data from /home/runner/.hydromt_data/data/v0.0.4/osm_landareas.gpkg
# 2021-05-18 09:07:09,606 - build - data_adapter - INFO - DataCatalog: Getting gebco RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/gebco.tif
# 2021-05-18 09:07:09,642 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.022, 45.140, 12.852, 45.665]
# 2021-05-18 09:07:09,749 - build - data_adapter - INFO - DataCatalog: Getting dtu10mdt_egm96 RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/dtu10mdt_egm96.tif
# 2021-05-18 09:07:09,784 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.022, 45.140, 12.852, 45.665]
# 2021-05-18 09:07:09,912 - build - sfincs - DEBUG - Mean vertical corection from MDT: 0.195
# 2021-05-18 09:07:10,033 - build - sfincs - DEBUG - Interpolate bathymetry at 6892 cells
# 2021-05-18 09:07:17,923 - build - sfincs - INFO - Bathymetry data merged; buffer 0 cells
# 2021-05-18 09:07:17,925 - build - sfincs - INFO - Bathymetry generated
# 2021-05-18 09:07:17,955 - build - model_api - DEBUG - Default config read from /usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/data/sfincs/sfincs.inp
# 2021-05-18 09:07:17,989 - build - sfincs - INFO - Mask generated; 192747 active cells.
# 2021-05-18 09:07:17,990 - build - sfincs - INFO - Write model data to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs
# 2021-05-18 09:07:17,990 - build - model_api - INFO - Writing model config to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs/sfincs.inp
# 2021-05-18 09:07:17,990 - build - sfincs - DEBUG - Derive indices from mask.
# 2021-05-18 09:07:17,995 - build - sfincs - INFO - Write GIS raster files to 'gis' subfolder
# 2021-05-18 09:07:18,008 - build - sfincs - INFO - Write staticgeom files

# %% [markdown]
# This should work without any errors.
#
# The example above means the following: run **hydromt build** with:
#
# * `sfincs` : i.e. build a sfincs model
# * `./venice_sfincs` : output model folder
# * `"{'bbox': [12.047909,45.15809,12.833432,45.646944]}"` : make a model that is active for the full given bounding box. All *REGION* options are described in the [docs](https://deltares.github.io/hydromt/latest/user_guide/cli.html#region-options)
# * `-vv` : give some extra verbosity (2 * v) to display feedback on screen. Now debug messages are provided.
#
# NOTE: As we did not specify a model configuration, only the base maps (topography) have been setup using default parameters. To build a complete model we need the use a configuraton ini-file.
#
# We can now inspect the newly created folder `./venice_sfincs`

# %%
# !ls ./venice_sfincs
# Out:
# gis  hydromt.log  sfincs.dep  sfincs.ind  sfincs.inp  sfincs.msk

# %% [markdown]
# The .log file contains the same messages as shown in the verbose messages during the building of the model. The files are standard sfincs formats and contain the following
# * .inp file : holds the model's configuration
# * .dep file : holds the bathymetry in the typical format of sfincs
# * .msk file : mask file (0, inactive cells, 1, active cells, 2, boundary cells)
#
# Let us have a closer look at the model's configuration

# %%
fn_inp = './venice_sfincs/sfincs.inp'
with open(fn_inp, 'r') as f:
    txt = f.read()
print(txt)
# Out:
# mmax            = 633
# nmax            = 518
# dx              = 100.0
# dy              = 100.0
# x0              = 267900.0
# y0              = 5007300.0
# rotation        = 0
# tref            = 20000101 000000
# tstart          = 20000101 000000
# tstop           = 20000102 000000
# dtout           = 3600
# dthisout        = 600
# dtmaxout        = 86400
# advection       = 0
# alpha           = 0.75
# huthresh        = 0.05
# theta           = 0.9
# min_lev_hmax    = -1
# zsini           = 0
# qinf            = 0
# manning_land    = 0.04
# manning_sea     = 0.02
# rgh_lev_land    = 0
# depfile         = sfincs.dep
# mskfile         = sfincs.msk
# indexfile       = sfincs.ind
# inputformat     = bin
# outputformat    = net
# epsg            = 32633

# %% [markdown]
# We see that quite standard settings are used. The coordinate reference system (see `epsg`) is automatically chosen to the nearest UTM zone. We have not even considered the resolution. It is now 100 meters (see `dx` and `dy`). Let's assume we want a 150 meter model and rebuild it. The `--help` section showed that the `-r` option has to be used to change this.

# %%
# !hydromt build sfincs ./venice_sfincs_150 "{'bbox': [12.047909,45.15809,12.833432,45.646944]}" -r 150 -vv
# Out:
# 2021-05-18 09:07:20,092 - build - log - DEBUG - Writing log messages to new file /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150/hydromt.log.
# 2021-05-18 09:07:20,092 - build - log - INFO - HydroMT version: 0.4.1
# 2021-05-18 09:07:20,092 - build - main - INFO - Building instance of sfincs model at /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150.
# 2021-05-18 09:07:20,092 - build - main - INFO - User settings:
# 2021-05-18 09:07:20,092 - build - model_api - INFO - Initializing sfincs model from hydromt_sfincs (v0.1.0).
# 2021-05-18 09:07:20,092 - build - model_api - WARNING - Model dir already exists and files might be overwritten: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150/.
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.region: {'bbox': [12.047909, 45.15809, 12.833432, 45.646944]}
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.res: 150.0
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.crs: utm
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.basemaps_fn: merit_hydro
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.basin_index_fn: merit_hydro_index
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.landmask_fn: osm_landareas
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.bathymetry_fn: gebco
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.mdt_fn: dtu10mdt_egm96
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.merge_buffer: 0
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.mask_fn: None
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.dep_contour: -1
# 2021-05-18 09:07:20,093 - build - model_api - INFO - setup_basemaps.method: bilinear
# 2021-05-18 09:07:20,093 - build - data_adapter - INFO - Updating data sources from yml file /home/runner/.hydromt_data/data/v0.0.4/data_catalog.yml
# 2021-05-18 09:07:20,163 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/merit_hydro/{variable}.tif
# 2021-05-18 09:07:20,244 - build - basin_mask - DEBUG - Parsed region (kind=bbox): {'bbox': [12.047909, 45.15809, 12.833432, 45.646944]}
# 2021-05-18 09:07:20,405 - build - data_adapter - INFO - DataCatalog: Getting osm_landareas GeoDataFrame vector data from /home/runner/.hydromt_data/data/v0.0.4/osm_landareas.gpkg
# 2021-05-18 09:07:20,501 - build - data_adapter - INFO - DataCatalog: Getting gebco RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/gebco.tif
# 2021-05-18 09:07:20,535 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.022, 45.140, 12.852, 45.665]
# 2021-05-18 09:07:20,619 - build - data_adapter - INFO - DataCatalog: Getting dtu10mdt_egm96 RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/dtu10mdt_egm96.tif
# 2021-05-18 09:07:20,653 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.022, 45.140, 12.852, 45.665]
# 2021-05-18 09:07:20,764 - build - sfincs - DEBUG - Mean vertical corection from MDT: 0.193
# 2021-05-18 09:07:20,839 - build - sfincs - DEBUG - Interpolate bathymetry at 3488 cells
# 2021-05-18 09:07:24,203 - build - sfincs - INFO - Bathymetry data merged; buffer 0 cells
# 2021-05-18 09:07:24,205 - build - sfincs - INFO - Bathymetry generated
# 2021-05-18 09:07:24,224 - build - model_api - DEBUG - Default config read from /usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/data/sfincs/sfincs.inp
# 2021-05-18 09:07:24,259 - build - sfincs - INFO - Mask generated; 85974 active cells.
# 2021-05-18 09:07:24,259 - build - sfincs - INFO - Write model data to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150
# 2021-05-18 09:07:24,259 - build - model_api - INFO - Writing model config to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150/sfincs.inp
# 2021-05-18 09:07:24,260 - build - sfincs - DEBUG - Derive indices from mask.
# 2021-05-18 09:07:24,263 - build - sfincs - INFO - Write GIS raster files to 'gis' subfolder
# 2021-05-18 09:07:24,274 - build - sfincs - INFO - Write staticgeom files

# %%
fn_inp = './venice_sfincs_150/sfincs.inp'
with open(fn_inp, 'r') as f:
    txt = f.read()

print(txt)
# Out:
# mmax            = 422
# nmax            = 347
# dx              = 150.0
# dy              = 150.0
# x0              = 267900.0
# y0              = 5007150.0
# rotation        = 0
# tref            = 20000101 000000
# tstart          = 20000101 000000
# tstop           = 20000102 000000
# dtout           = 3600
# dthisout        = 600
# dtmaxout        = 86400
# advection       = 0
# alpha           = 0.75
# huthresh        = 0.05
# theta           = 0.9
# min_lev_hmax    = -1
# zsini           = 0
# qinf            = 0
# manning_land    = 0.04
# manning_sea     = 0.02
# rgh_lev_land    = 0
# depfile         = sfincs.dep
# mskfile         = sfincs.msk
# indexfile       = sfincs.ind
# inputformat     = bin
# outputformat    = net
# epsg            = 32633

# %% [markdown]
# It is clear that the `dx` and `dy` settings are changed.

# %% [markdown]
# ### Building a complete model (ready to run)

# %% [markdown]
# We can provide many more settings in an confuration (.ini) file instead of command line arguments. If you don't provide an ini file (as done above), only the basemaps component is build with default settings. To complete your model you can add more [model components](https://deltares.github.io/hydromt_sfincs/latest/user_guide/sfincs.html) to the model setup.
#
# Let's have a look a typical ini file for setting up coastal sfincs model, where each `[setup_<>]` refers to a model component. All options which end with `_fn` refers to a data source from the data catalog or a path to data on your machine, see [hydromt data](https://deltares.github.io/hydromt/latest/user_guide/data.html). In this case some sample data which is downloaded to your machine at `$USER_ROOT/.hydromt_data`

# %%
fn_ini = 'sfincs_coastal.ini'
with open(fn_ini, 'r') as f:
    txt = f.read()
print(txt)
# Out:
# [global]
# write_gis = True                # write addtional geotif and geojson files to gis subfolder
# config_fn = sfincs.inp          # name of sfincs config (inp) file
#
# [setup_config]
# tref = 20100101 000000
# tstart = 20100201 000000
# tstop = 20100210 000000
# alpha = 0.5
# zsini = 0.5
#
# [setup_basemaps]
# basemaps_fn = merit_hydro       # hydrography basemaps ['elevtn', 'flwdir', 'uparea', 'basins']
# landmask_fn = osm_landareas     # land polygon
# crs = utm                       # model CRS (must be UTM zone)
# bathymetry_fn = gebco           # bathymetry ['elevtn']
# mdt_fn = dtu10mdt_egm96         # mean dynamic topography ['mdt']
# merge_buffer = 0                # buffer (cells) between elevation and bathymetry data filled with 'linear' interpolation
# mask_fn = None                  # polygon to mask active model cells
# dep_contour = -1                # mimimum depth threshold for active model cells
#
# [setup_cn_infiltration]
# cn_fn = gcn250                  # curve number source
# antecedent_runoff_conditions = avg # for gcn250: {'dry', 'avg', 'wet'}
#
# [setup_manning_roughness]
# lulc_fn = vito                  # land-use land-cover source
# map_fn = None                   # mapping file. read from hydromt/data/lulc/{lulc_fn}_mapping.csv if None
#
# [setup_h_forcing]
# gauges_fn = gtsmv3_eu_era5      # waterlevel gauge data
# timeseries_fn = None            # timeseries data at waterlevel gauges
# mdt_fn = dtu10mdt_egm96         # mean dynamic topography ['mdt']
# buffer = 1e4                    # buffer around model region to select gauges
#
# [setup_p_forcing_gridded]
# precip_fn = era5_hourly         # gridded precipitation data ['precip']
# dst_res = None                  # output resolution (m)

# %% [markdown]
# You can see the following sections:
# * `[global]`: arguments passed to SfincsModel initialization. With the `write_gis` flag a copy of the model schmatization in GIS compatible formats is saved in the gis subfolder.
# * `[setup_config]`: arguments which are forwarded to the scinf model configuration file sfincs.inp
# * `[setup_basemaps]`: basic information required for the elevation, bathymetry, land mask. These are the typical demanded static layers that any sfincs model needs. Here you may for instance consider altering the elevation and bathymetry data for local data sources. These then have to be supplied in the `data_catalog.yml`.
# * `[setup_cn_infiltration]`: infiltration curve number maps, see [sfincs docs](https://sfincs.readthedocs.io/en/latest/input.html?highlight=curve#spatially-varying-curve-number) for more information
# * `[setup_manning_roughness]`: configuration of the Manning roughness values, typically consisting of a land use or land cover map, and a lookup table that relates land use classes to manning roughness values in sec m$^{-1/3}$
# * `[setup_h_forcing]`: water level forcing data. This can be provided as a NetCDF file following CF-conventions for point time series data.
# * `[setup_p_forcing_gridded]`: gridded precipitation data, that can be used to do compound flood simulations. The `[setup_cn_infiltration]` is then quite essential to include.

# %% [markdown]
# To build a model from scratch add the ini file to the command line `hydromt build` method

# %%
# !hydromt build sfincs ./venice_sfincs_150_full "{'bbox': [12.047909,45.15809,12.833432,45.646944]}" -r 150 -i sfincs_coastal.ini -vv
# Out:
# 2021-05-18 09:07:26,210 - build - log - DEBUG - Writing log messages to new file /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150_full/hydromt.log.
# 2021-05-18 09:07:26,210 - build - log - INFO - HydroMT version: 0.4.1
# 2021-05-18 09:07:26,210 - build - main - INFO - Building instance of sfincs model at /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150_full.
# 2021-05-18 09:07:26,210 - build - main - INFO - User settings:
# 2021-05-18 09:07:26,212 - build - model_api - INFO - Initializing sfincs model from hydromt_sfincs (v0.1.0).
# 2021-05-18 09:07:26,212 - build - model_api - WARNING - Model dir already exists and files might be overwritten: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150_full/.
# 2021-05-18 09:07:26,212 - build - model_api - DEBUG - Setting model config options.
# 2021-05-18 09:07:26,213 - build - model_api - DEBUG - Default config read from /usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/data/sfincs/sfincs.inp
# 2021-05-18 09:07:26,213 - build - model_api - INFO - setup_basemaps.region: {'bbox': [12.047909, 45.15809, 12.833432, 45.646944]}
# 2021-05-18 09:07:26,213 - build - model_api - INFO - setup_basemaps.res: 150.0
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.crs: utm
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.basemaps_fn: merit_hydro
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.basin_index_fn: merit_hydro_index
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.landmask_fn: osm_landareas
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.bathymetry_fn: gebco
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.mdt_fn: dtu10mdt_egm96
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.merge_buffer: 0
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.mask_fn: None
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.dep_contour: -1
# 2021-05-18 09:07:26,214 - build - model_api - INFO - setup_basemaps.method: bilinear
# 2021-05-18 09:07:26,214 - build - data_adapter - INFO - Updating data sources from yml file /home/runner/.hydromt_data/data/v0.0.4/data_catalog.yml
# 2021-05-18 09:07:26,287 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/merit_hydro/{variable}.tif
# 2021-05-18 09:07:26,367 - build - basin_mask - DEBUG - Parsed region (kind=bbox): {'bbox': [12.047909, 45.15809, 12.833432, 45.646944]}
# 2021-05-18 09:07:26,538 - build - data_adapter - INFO - DataCatalog: Getting osm_landareas GeoDataFrame vector data from /home/runner/.hydromt_data/data/v0.0.4/osm_landareas.gpkg
# 2021-05-18 09:07:26,644 - build - data_adapter - INFO - DataCatalog: Getting gebco RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/gebco.tif
# 2021-05-18 09:07:26,680 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.022, 45.140, 12.852, 45.665]
# 2021-05-18 09:07:26,771 - build - data_adapter - INFO - DataCatalog: Getting dtu10mdt_egm96 RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/dtu10mdt_egm96.tif
# 2021-05-18 09:07:26,808 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.022, 45.140, 12.852, 45.665]
# 2021-05-18 09:07:26,924 - build - sfincs - DEBUG - Mean vertical corection from MDT: 0.193
# 2021-05-18 09:07:26,993 - build - sfincs - DEBUG - Interpolate bathymetry at 3488 cells
# 2021-05-18 09:07:30,353 - build - sfincs - INFO - Bathymetry data merged; buffer 0 cells
# 2021-05-18 09:07:30,354 - build - sfincs - INFO - Bathymetry generated
# 2021-05-18 09:07:30,408 - build - sfincs - INFO - Mask generated; 85974 active cells.
# 2021-05-18 09:07:30,409 - build - model_api - INFO - setup_cn_infiltration.cn_fn: gcn250
# 2021-05-18 09:07:30,409 - build - model_api - INFO - setup_cn_infiltration.antecedent_runoff_conditions: avg
# 2021-05-18 09:07:30,409 - build - data_adapter - INFO - DataCatalog: Getting gcn250 RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/gcn250/{variable}.tif
# 2021-05-18 09:07:30,447 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.021, 45.198, 12.837, 45.666]
# 2021-05-18 09:07:30,533 - build - model_api - INFO - setup_manning_roughness.lulc_fn: vito
# 2021-05-18 09:07:30,534 - build - model_api - INFO - setup_manning_roughness.map_fn: None
# 2021-05-18 09:07:30,534 - build - data_adapter - INFO - DataCatalog: Getting vito RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.4/vito.tif
# 2021-05-18 09:07:30,571 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.021, 45.198, 12.837, 45.666]
# 2021-05-18 09:07:30,640 - build - landuse - INFO - Deriving N using average resampling (nodata=-999.0).
# 2021-05-18 09:07:30,766 - build - model_api - INFO - setup_h_forcing.gauges_fn: gtsmv3_eu_era5
# 2021-05-18 09:07:30,767 - build - model_api - INFO - setup_h_forcing.timeseries_fn: None
# 2021-05-18 09:07:30,767 - build - model_api - INFO - setup_h_forcing.mdt_fn: dtu10mdt_egm96
# 2021-05-18 09:07:30,767 - build - model_api - INFO - setup_h_forcing.buffer: 10000.0
# 2021-05-18 09:07:30,768 - build - data_adapter - INFO - DataCatalog: Getting gtsmv3_eu_era5 GeoDataset netcdf data from /home/runner/.hydromt_data/data/v0.0.4/gtsmv3_eu_era5.nc
# 2021-05-18 09:07:31,164 - build - data_adapter - INFO - GeoDataset: Read netcdf data and clip to geom - [267900.000, 5008500.000, 331200.000, 5059200.000].
# 2021-05-18 09:07:31,245 - build - data_adapter - DEBUG - GeoDataset: Slicing time dim (datetime.datetime(2010, 2, 1, 0, 0), datetime.datetime(2010, 2, 10, 0, 0))
# 2021-05-18 09:07:31,246 - build - sfincs - DEBUG - waterlevel forcing: setting data at 16 points.
# 2021-05-18 09:07:31,305 - build - sfincs - DEBUG - waterlevel forcing: updating sfincs.inp.
# 2021-05-18 09:07:31,305 - build - model_api - INFO - setup_p_forcing_gridded.precip_fn: era5_hourly
# 2021-05-18 09:07:31,305 - build - model_api - INFO - setup_p_forcing_gridded.dst_res: None
# 2021-05-18 09:07:31,305 - build - data_adapter - INFO - DataCatalog: Getting era5_hourly RasterDataset netcdf data from /home/runner/.hydromt_data/data/v0.0.4/era5_hourly.nc
# 2021-05-18 09:07:31,316 - build - data_adapter - DEBUG - RasterDataset: Slicing time dim (datetime.datetime(2010, 2, 1, 0, 0), datetime.datetime(2010, 2, 10, 0, 0))
# 2021-05-18 09:07:31,346 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [12.021, 45.198, 12.837, 45.666]
# 2021-05-18 09:07:31,403 - build - data_adapter - DEBUG - RasterDataset: Convert units for 1 variables.
# 2021-05-18 09:07:31,427 - build - sfincs - INFO - Write model data to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150_full
# 2021-05-18 09:07:31,427 - build - model_api - INFO - Writing model config to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/venice_sfincs_150_full/sfincs.inp
# 2021-05-18 09:07:31,428 - build - sfincs - DEBUG - Derive indices from mask.
# 2021-05-18 09:07:31,462 - build - sfincs - INFO - Write GIS raster files to 'gis' subfolder
# 2021-05-18 09:07:31,518 - build - sfincs - INFO - Write staticgeom files
# 2021-05-18 09:07:31,538 - build - sfincs - INFO - Write forcing files

# %%
# !ls ./venice_sfincs_150_full
# Out:
# gis	     precip.nc	 sfincs.bzs  sfincs.ind  sfincs.man  sfincs.scs
# hydromt.log  sfincs.bnd  sfincs.dep  sfincs.inp  sfincs.msk

# %% [markdown]
# ### Inspecting the model
# Let's have a closer look at the model. To interact with a model within a notebook or python script, we need to load a number of modules.

# %%
# %matplotlib inline
import hydromt
import os

# %% [markdown]
# Now we can load the model in memory and inspect it.
#
# Note that based on the global datasets the lagoon bathymetry is not well represented. A better merge between MERIT hydro topography and GEBCO bathymetry can be achieved by providing an better coastline shapefile (by default OSM based) which determines which dataset is used where.

# %%
# define the model's configuration file
root = r'./venice_sfincs_150_full'

# read the model with hydromt sfincs methods
mod = hydromt.SfincsModel(root=root, mode="r")
mod.read()
mod.plot_basemap(figsize=(12, 8))
# Out:
# (<Figure size 864x576 with 2 Axes>,
#  <GeoAxesSubplot:title={'center':'SFINCS dep map'}, xlabel='x coordinate UTM zone 33N [m]', ylabel='y coordinate UTM zone 33N [m]'>)

# %% [markdown]
# ### Next steps
# You can update an existing model, e.g. to replace parameterisations or add forcing. this is descibed in a follow-up notebook `sfincs_update_model.ipynb`
