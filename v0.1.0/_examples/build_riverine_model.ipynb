# %% [markdown]
# ## Build a riverine SFINCS model from scratch

# %% [markdown]
# This notebook demonstrates how to prepare **SFINCS** model from scratch using the command line interace (CLI).

# %% [markdown]
# All lines in this notebook which start with `!` are executed from the command line. Within the notebook environment the logging messages are shown after completion. You can also copy these lines and paste these in your shell to get more direct feedback.

# %% [markdown]
# ### hydroMT CLI build interface

# %% [markdown]
# Lets first check if the SFINCS model is recognized by hydromt

# %%
# this should return "sfincs"
# !hydromt --models
# Out:
# hydroMT model plugins: sfincs

# %% [markdown]
# Using the **hydromt build** API we can setup a complete model from scratch. Let's get an overview of all the available options:

# %%
# !hydromt build --help
# Out:
# Usage: hydromt build [OPTIONS] MODEL MODEL_ROOT REGION
#
#   Build models from source data.
#
#   Example usage:
#   --------------
#
#   To build a wflow model for a subbasin using and point coordinates snapped to cells with stream order >= 4
#   hydromt build wflow /path/to/model_root "{'subbasin': [-7.24, 62.09], 'strord': 4}" -i /path/to/wflow_config.ini
#
#   To build a wflow model based on basin ID
#   hydromt build wflow /path/to/model_root "{'basin': 230001006}"
#
#   To build a sfincs model based on a bbox (for Texel)
#   hydromt build sfincs /path/to/model_root "{'bbox': [4.6891,52.9750,4.9576,53.1994]}"
#
# Options:
#   -r, --res FLOAT             Model resolution in model src.
#   --build-base / --build-all  Deprecated!
#   --opt TEXT                  Component specific keyword arguments, see the
#                               setup_<component> method of the specific model
#                               for more information about the arguments.
#
#   -i, --config PATH           Path to hydroMT configuration file, for the
#                               model specific implementation.
#
#   -d, --data PATH             File path to yml data sources file. See
#                               documentation for required yml file format.
#
#   --dd, --deltares-data       Parse default deltares data yml from
#                               https://github.com/DirkEilander/hydromt-
#                               artifacts/releases
#
#   -q, --quiet                 Decrease verbosity.
#   -v, --verbose               Increase verbosity.
#   --help                      Show this message and exit.

# %% [markdown]
# ### setup SFINCS model base layers

# %%
# NOTE: copy this line (without !) to your shell for more direct feedback
# !hydromt build sfincs "./sfincs_test_base" "{'bbox': [11.975098,45.786918,12.271385,45.938019]}" -r 100 -vv
# Out:
# 2021-05-17 08:27:51,249 - build - log - DEBUG - Writing log messages to new file /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_base/hydromt.log.
# 2021-05-17 08:27:51,249 - build - log - INFO - HydroMT version: 0.4.0
# 2021-05-17 08:27:51,249 - build - main - INFO - Building instance of sfincs model at /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_base.
# 2021-05-17 08:27:51,249 - build - main - INFO - User settings:
# 2021-05-17 08:27:51,249 - build - model_api - WARNING - Model dir already exists and files might be overwritten: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_base/.
# 2021-05-17 08:27:51,249 - build - model_api - DEBUG - setup_basemaps.region: {'bbox': [11.975098, 45.786918, 12.271385, 45.938019]}
# 2021-05-17 08:27:51,249 - build - model_api - DEBUG - setup_basemaps.res: 100.0
# 2021-05-17 08:27:51,249 - build - model_api - DEBUG - setup_basemaps.crs: utm
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.basemaps_fn: merit_hydro
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.basin_index_fn: merit_hydro_index
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.landmask_fn: osm_landareas
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.bathymetry_fn: gebco
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.mdt_fn: dtu10mdt_egm96
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.merge_buffer: 0
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.mask_fn: None
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.dep_contour: -1
# 2021-05-17 08:27:51,250 - build - model_api - DEBUG - setup_basemaps.method: bilinear
# 2021-05-17 08:27:51,250 - build - data_adapter - INFO - Updating data sources from yml file /home/runner/.hydromt_data/data/v0.0.2/data_catalog.yml
# 2021-05-17 08:27:51,328 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.2/merit_hydro/{variable}.tif
# 2021-05-17 08:27:51,417 - build - basin_mask - DEBUG - Parsed region (kind=bbox): {'bbox': [11.975098, 45.786918, 12.271385, 45.938019]}
# 2021-05-17 08:27:51,551 - build - data_adapter - INFO - DataCatalog: Getting osm_landareas GeoDataFrame vector data from /home/runner/.hydromt_data/data/v0.0.2/osm_landareas.gpkg
# 2021-05-17 08:27:51,661 - build - sfincs - INFO - Bathymetry generated
# 2021-05-17 08:27:51,674 - build - model_api - DEBUG - Default config read from /usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/data/sfincs/sfincs.inp
# 2021-05-17 08:27:51,706 - build - sfincs - INFO - Mask generated; 42186 active cells.
# 2021-05-17 08:27:51,706 - build - sfincs - INFO - Write model data to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_base
# 2021-05-17 08:27:51,706 - build - model_api - INFO - Writing model config to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_base/sfincs.inp
# 2021-05-17 08:27:51,707 - build - sfincs - DEBUG - Derive indices from mask.
# 2021-05-17 08:27:51,708 - build - sfincs - INFO - Write GIS raster files to 'gis' subfolder
# 2021-05-17 08:27:51,718 - build - sfincs - INFO - Write staticgeom files

# %% [markdown]
# The example above means the following: run **hydromt build** with:
#
# * `sfincs` : i.e. build a sfincs model
# * `./sfincs_test_base` : output model folder
# * `"{'bbox': [11.975098,45.786918,12.271385,45.938019]}"` : make a model that is active for the full given bounding box. All *REGION* options are described in the [docs](https://deltares.github.io/hydromt/latest/user_guide/cli.html#region-options)
# * `-r 100` : build the model at a 100 meter resolution
# * `-vv` : give some extra verbosity (2 * v) to display feedback on screen. Now debug messages are provided.
#
# NOTE: As we did not specify a model configuration, only the base maps (topography) have been setup using default parameters. To build a complete model we need the use a configuraton ini-file.

# %% [markdown]
# ### Model setup configuration

# %% [markdown]
# The ini-file contains the model setup configuration and determines which components are build and in which order and optionally sets non-default arguments for each component. This configuration is passed to hydromt using `-i <path_to_ini_file>`. We have prepared several example ini-files which are available in the model repository [examples folder](https://github.com/Deltares/hydromt_sfincs/tree/main/examples) and from the [docs(build_configuration)](https://deltares.github.io/hydromt_sfincs/latest/user_guide/sfincs/build_configuration.html).
#
# Each header as shown between `[...]` (e.g. `[setup_basemaps]`) corresponds to a model component. All model components are explained in the [docs(model_components)](https://deltares.github.io/hydromt_sfincs/latest/user_guide/sfincs/components.html).

# %% [markdown]
# We will load the default SFINCS build ini file for inspection:

# %%
fn_ini = 'sfincs_riverine.ini'
with open(fn_ini, 'r') as f:
    txt = f.read()
print(txt)
# Out:
# [global]
# write_gis = True                # write addtional geotif and geojson files to gis subfolder
# config_fn = sfincs.inp          # name of sfincs config (inp) file
#
# [setup_config]
# tref = 20210101 000000
# tstart = 20210101 000000
# tstop = 20210103 000000
# alpha = 0.5
# zsini = 0.0
# dtmaxout = 172800
#
# [setup_basemaps]
# basemaps_fn = merit_hydro       # hydrography basemaps ['elevtn', 'flwdir', 'uparea', 'basins']
# landmask_fn = osm_landareas     # land polygon
# crs = utm                       # model CRS (must be UTM zone)
# bathymetry_fn = gebco           # bathymetry ['elevtn']
# mdt_fn = dtu10mdt_egm96         # mean dynamic topography ['mdt']
# merge_buffer = 0                # buffer (cells) between elevation and bathymetry data filled with 'linear' interpolation
# mask_fn = None                  # polygon to mask active model cells
# dep_contour = -1                # mimimum depth threshold for active model cells
#
# [setup_cn_infiltration]
# cn_fn = gcn250                  # curve number source
# antecedent_runoff_conditions = avg # for gcn250: {'dry', 'avg', 'wet'}
#
# [setup_manning_roughness]
# lulc_fn = vito                  # land-use land-cover source
# map_fn = None                   # mapping file. read from hydromt/data/lulc/{lulc_fn}_mapping.csv if None
#
# [setup_river_inflow]
# basemaps_fn = merit_hydro       # hydrography basemaps [flwdir', 'uparea'], should be same as under [basemaps]
# river_upa = 25                  # Mimimum upstream area threshold (km2) of river cells
#
# [setup_river_outflow]
# basemaps_fn = merit_hydro       # hydrography basemaps [flwdir', 'uparea'], should be same as under [basemaps]
# river_upa = 5                   # Mimimum upstream area threshold (km2) of river cells
# outflow_width = 2500             # The width [m] of the outflow boundary
#
# [setup_gauges]
# gauges_fn = riverine_gauges.csv   # gauges point locations
# crs = 4326                      # epsg-code for gauges (only used if not in gauges_fn metadata, e.g. when csv file)
#
# [setup_q_forcing]
# gauges_fn = None                #  discharge gauge data (locations point file or nc file with timeseries and point coordinates)
# timeseries_fn = discharge_input_sfincs.csv   # timeseries data at discharge gauges

# %% [markdown]
# ### Data for model setup

# %% [markdown]
# The `<...>_fn` arguments correspond to a data source from the `DataCatalog` which is based on a yml-file with references to the data paths/urls and how the data should be read. This file can be provided to hydromt using `-d <path_to_yml_file>`.
#
# By default some example data for the Piave basin will be downloaded to `$USER_ROOT$/.hydromt_data/` which is also used for this example. An overview of the available example data is provided [here](https://deltares.github.io/hydromt/latest/user_guide/data.html#available-global-datasets)
# This example data is a based on the data which available from the Deltares p-drive.
# If you have acces to this drive, a pre-configured catalog file can be loaded using the `--dd` flag.
#
# More background how to write a data catalog yml file can be found in the [hydromt core docs](https://deltares.github.io/hydromt/latest/user_guide/data.html)

# %% [markdown]
# ### Setup complete SFINCS model

# %%
# NOTE: copy this line (without !) to your shell for more direct feedback
# !hydromt build sfincs "./sfincs_test_full" "{'bbox': [11.975098,45.786918,12.271385,45.938019]}" -r 50 -i sfincs_riverine.ini -vv
# Out:
# 2021-05-17 08:27:53,764 - build - log - DEBUG - Writing log messages to new file /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_full/hydromt.log.
# 2021-05-17 08:27:53,764 - build - log - INFO - HydroMT version: 0.4.0
# 2021-05-17 08:27:53,765 - build - main - INFO - Building instance of sfincs model at /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_full.
# 2021-05-17 08:27:53,765 - build - main - INFO - User settings:
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - global.write_gis: True
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - global.config_fn: sfincs.inp
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_config.tref: 20210101 000000
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_config.tstart: 20210101 000000
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_config.tstop: 20210103 000000
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_config.alpha: 0.5
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_config.zsini: 0.0
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_config.dtmaxout: 172800
# 2021-05-17 08:27:53,767 - build - cli_utils - INFO - setup_basemaps.basemaps_fn: merit_hydro
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.landmask_fn: osm_landareas
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.crs: utm
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.bathymetry_fn: gebco
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.mdt_fn: dtu10mdt_egm96
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.merge_buffer: 0
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.mask_fn: None
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_basemaps.dep_contour: -1
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_cn_infiltration.cn_fn: gcn250
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_cn_infiltration.antecedent_runoff_conditions: avg
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_manning_roughness.lulc_fn: vito
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_manning_roughness.map_fn: None
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_river_inflow.basemaps_fn: merit_hydro
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_river_inflow.river_upa: 25
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_river_outflow.basemaps_fn: merit_hydro
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_river_outflow.river_upa: 5
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_river_outflow.outflow_width: 2500
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_gauges.gauges_fn: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/riverine_gauges.csv
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_gauges.crs: 4326
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_q_forcing.gauges_fn: None
# 2021-05-17 08:27:53,768 - build - cli_utils - INFO - setup_q_forcing.timeseries_fn: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/discharge_input_sfincs.csv
# 2021-05-17 08:27:53,768 - build - model_api - WARNING - Model dir already exists and files might be overwritten: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_full/.
# 2021-05-17 08:27:53,769 - build - model_api - DEBUG - Setting model config options.
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - Default config read from /usr/share/miniconda/envs/hydromt-sfincs/lib/python3.9/site-packages/hydromt_sfincs/data/sfincs/sfincs.inp
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - setup_basemaps.region: {'bbox': [11.975098, 45.786918, 12.271385, 45.938019]}
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - setup_basemaps.res: 50.0
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - setup_basemaps.crs: utm
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - setup_basemaps.basemaps_fn: merit_hydro
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - setup_basemaps.basin_index_fn: merit_hydro_index
# 2021-05-17 08:27:53,770 - build - model_api - DEBUG - setup_basemaps.landmask_fn: osm_landareas
# 2021-05-17 08:27:53,771 - build - model_api - DEBUG - setup_basemaps.bathymetry_fn: gebco
# 2021-05-17 08:27:53,771 - build - model_api - DEBUG - setup_basemaps.mdt_fn: dtu10mdt_egm96
# 2021-05-17 08:27:53,771 - build - model_api - DEBUG - setup_basemaps.merge_buffer: 0
# 2021-05-17 08:27:53,771 - build - model_api - DEBUG - setup_basemaps.mask_fn: None
# 2021-05-17 08:27:53,771 - build - model_api - DEBUG - setup_basemaps.dep_contour: -1
# 2021-05-17 08:27:53,771 - build - model_api - DEBUG - setup_basemaps.method: bilinear
# 2021-05-17 08:27:53,771 - build - data_adapter - INFO - Updating data sources from yml file /home/runner/.hydromt_data/data/v0.0.2/data_catalog.yml
# 2021-05-17 08:27:53,846 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.2/merit_hydro/{variable}.tif
# 2021-05-17 08:27:53,939 - build - basin_mask - DEBUG - Parsed region (kind=bbox): {'bbox': [11.975098, 45.786918, 12.271385, 45.938019]}
# 2021-05-17 08:27:54,091 - build - data_adapter - INFO - DataCatalog: Getting osm_landareas GeoDataFrame vector data from /home/runner/.hydromt_data/data/v0.0.2/osm_landareas.gpkg
# 2021-05-17 08:27:54,200 - build - sfincs - INFO - Bathymetry generated
# 2021-05-17 08:27:54,255 - build - sfincs - INFO - Mask generated; 167442 active cells.
# 2021-05-17 08:27:54,256 - build - model_api - DEBUG - setup_cn_infiltration.cn_fn: gcn250
# 2021-05-17 08:27:54,256 - build - model_api - DEBUG - setup_cn_infiltration.antecedent_runoff_conditions: avg
# 2021-05-17 08:27:54,256 - build - data_adapter - INFO - DataCatalog: Getting gcn250 RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.2/gcn250/{variable}.tif
# 2021-05-17 08:27:54,292 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [11.966, 45.779, 12.279, 45.946]
# 2021-05-17 08:27:54,380 - build - model_api - DEBUG - setup_manning_roughness.lulc_fn: vito
# 2021-05-17 08:27:54,380 - build - model_api - DEBUG - setup_manning_roughness.map_fn: None
# 2021-05-17 08:27:54,380 - build - data_adapter - INFO - DataCatalog: Getting vito RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.2/vito.tif
# 2021-05-17 08:27:54,418 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [11.966, 45.779, 12.279, 45.946]
# 2021-05-17 08:27:54,485 - build - landuse - INFO - Deriving N using average resampling (nodata=-999.0).
# 2021-05-17 08:27:54,538 - build - model_api - DEBUG - setup_river_inflow.river_upa: 25
# 2021-05-17 08:27:54,538 - build - model_api - DEBUG - setup_river_inflow.basemaps_fn: merit_hydro
# 2021-05-17 08:27:54,538 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.2/merit_hydro/{variable}.tif
# 2021-05-17 08:27:54,629 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [11.966, 45.779, 12.279, 45.946]
# 2021-05-17 08:27:54,737 - build - sfincs - DEBUG - Get river cells for inflow source points; upstream area threshold: 25 km2.
# 2021-05-17 08:27:55,695 - build - sfincs - DEBUG - Set river source points (.src).
# 2021-05-17 08:27:56,580 - build - sfincs - DEBUG - 3 river inflow point locations set.
# 2021-05-17 08:27:56,585 - build - sfincs - DEBUG - discharge forcing: setting data at 3 points.
# 2021-05-17 08:27:56,597 - build - sfincs - DEBUG - discharge forcing: updating sfincs.inp.
# 2021-05-17 08:27:56,597 - build - sfincs - DEBUG - Vectorize river.
# 2021-05-17 08:27:56,908 - build - model_api - DEBUG - setup_river_outflow.river_upa: 5
# 2021-05-17 08:27:56,908 - build - model_api - DEBUG - setup_river_outflow.outflow_width: 2500
# 2021-05-17 08:27:56,908 - build - model_api - DEBUG - setup_river_outflow.basemaps_fn: merit_hydro
# 2021-05-17 08:27:56,908 - build - data_adapter - INFO - DataCatalog: Getting merit_hydro RasterDataset raster data from /home/runner/.hydromt_data/data/v0.0.2/merit_hydro/{variable}.tif
# 2021-05-17 08:27:56,998 - build - data_adapter - DEBUG - RasterDataset: Clip with geom - [11.966, 45.779, 12.279, 45.946]
# 2021-05-17 08:27:57,104 - build - sfincs - DEBUG - Get river cells for outflow points; upstream area threshold: 5 km2.
# 2021-05-17 08:27:57,125 - build - sfincs - DEBUG - Set msk=3 outflow points.
# 2021-05-17 08:27:57,188 - build - sfincs - DEBUG - 11 river outflow point locations set.
# 2021-05-17 08:27:57,188 - build - sfincs - DEBUG - Vectorize rivers used for setting outflow points.
# 2021-05-17 08:27:57,281 - build - model_api - DEBUG - setup_gauges.gauges_fn: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/riverine_gauges.csv
# 2021-05-17 08:27:57,282 - build - data_adapter - INFO - DataCatalog: Getting riverine_gauges GeoDataFrame csv data from /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/riverine_gauges.csv
# 2021-05-17 08:27:57,351 - build - sfincs - INFO - obs set based on /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/riverine_gauges.csv
# 2021-05-17 08:27:57,352 - build - model_api - DEBUG - setup_q_forcing.gauges_fn: None
# 2021-05-17 08:27:57,352 - build - model_api - DEBUG - setup_q_forcing.timeseries_fn: /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/discharge_input_sfincs.csv
# 2021-05-17 08:27:57,359 - build - sfincs - DEBUG - discharge forcing: add time series to preset gauges.
# 2021-05-17 08:27:57,359 - build - sfincs - DEBUG - discharge forcing: setting data at 3 points.
# 2021-05-17 08:27:57,361 - build - model_api - WARNING - Replacing forcing: dis
# 2021-05-17 08:27:57,371 - build - sfincs - DEBUG - discharge forcing: updating sfincs.inp.
# 2021-05-17 08:27:57,371 - build - sfincs - INFO - Write model data to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_full
# 2021-05-17 08:27:57,371 - build - model_api - INFO - Writing model config to /home/runner/work/hydromt_sfincs/hydromt_sfincs/docs/_examples/sfincs_test_full/sfincs.inp
# 2021-05-17 08:27:57,372 - build - sfincs - DEBUG - Derive indices from mask.
# 2021-05-17 08:27:57,432 - build - sfincs - INFO - Write GIS raster files to 'gis' subfolder
# 2021-05-17 08:27:57,497 - build - sfincs - INFO - Write staticgeom files
# 2021-05-17 08:27:57,759 - build - sfincs - INFO - Write forcing files

# %% [markdown]
# With this example we build a complete SFINCS model including forcing. Compared to the previous **hydromt build** we have added:
# * `-i sfincs_riverine.ini` : setup configuration file including all components to build and their arguments

# %% [markdown]
# Next we check which files have been created. The model root should contain two netcdf (.nc) files, one for the staticmaps and one for the forcing data, a SFINCS configuration (sfincs.inp) file. These files are sufficient to run the SFINCS model. In addition several geometry (.geojson) files are saved in the *staticgeoms* folder.  Finally, the setup process is logged in the hydromt.log file.

# %%
import os
root = 'sfincs_test_full'
for path, _, files in os.walk(root):
    print(path)
    for name in files:
        print(f' - {name}')
# Out:
# sfincs_test_full
#  - sfincs.man
#  - sfincs.ind
#  - sfincs.msk
#  - sfincs.dep
#  - hydromt.log
#  - sfincs.inp
#  - sfincs.obs
#  - sfincs.src
#  - sfincs.scs
#  - sfincs.dis
# sfincs_test_full/gis
#  - rivers.geojson
#  - bbox.geojson
#  - rivers_out.geojson
#  - dep.tif
#  - obs.geojson
#  - src.geojson
#  - manning.tif
#  - scs.tif
#  - region.geojson
#  - msk.tif

# %% [markdown]
# ### Visualize and/or inspect model schematization

# %% [markdown]
# ### Inspecting the model
# Let's have a closer look at the model. To interact with a model within a notebook or python script, we need to load a number of modules.

# %%
# %matplotlib inline
import hydromt
import os

# %% [markdown]
# Now we can load the model in memory and inspect it.
# Shown is the elevation in the SFINCS model as map, the main rivers as blue lines that determine the inflow locations, the minor rivers in red lines that determine the outflow locations and discharge input points as numbered triangles.

# %%
# define the model's configuration file
root = r'./sfincs_test_full'
# read the model with hydromt sfincs methods
mod = hydromt.SfincsModel(root=root, mode="r")
mod.read()

# %%
mod.plot_basemap(geoms=['src', 'obs', 'rivers', 'rivers_out'], figsize=(14, 14*0.65), legend_kwargs=dict(ncol=2))
# Out:
# (<Figure size 1008x655.2 with 2 Axes>,
#  <GeoAxesSubplot:title={'center':'SFINCS dep map'}, xlabel='x coordinate UTM zone 33N [m]', ylabel='y coordinate UTM zone 33N [m]'>)

# %%
mod.plot_forcing()
# Out:
# (<Figure size 432x216 with 1 Axes>,
#  [<AxesSubplot:title={'center':'SFINCS discharge boundaries (dis)'}, xlabel='time', ylabel='discharge [m3.s-1]'>])
